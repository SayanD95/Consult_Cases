# %% [markdown]
# # Data for FINCASH revenue

# %%
import pandas as pd

# %%
revenue_df = pd.read_csv('Case1.csv')

# %%
revenue_df
# Out:
#            Year  Number  Revenue
# 0       2019-20     100       18
# 1       2020-21     230       42
# 2       2021-22     245       48
# 3  2022-present     250       50

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Configuring styles
sns.set_style("darkgrid")
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### Number of Clients have increased with year

# %%
plt.title("Variation of the Number of clients in millions with year")
plt.xlabel('Year')
plt.ylabel('Clients')
plt.bar(revenue_df.Year, revenue_df.Number, color=(0.2, 0.4, 0.6, 0.6));

# %% [markdown]
# ### The Revenue has increased with year

# %%
plt.title("Variation of the Revenue in millions with year")
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.bar(revenue_df.Year, revenue_df.Revenue, color=(0.8, 0.4, 0.4, 0.6));

# %% [markdown]
# ### Clientele and Revenue Growth

# %%
revenue_growth = [0, 2400/18, 600/42, 200/48]
client_growth = [0, 130, 1500/230, 500/245]

# %%
revenue_df['Client_Growth'] = client_growth
revenue_df['Revenue_Growth'] = revenue_growth

# %%
plt.bar(revenue_df.Year, revenue_df.Client_Growth, color=(0.3, 0.8, 0.4));
plt.xlabel('Year')
plt.ylabel('Clientele Growth')
plt.title('Clientele Growth in % with Time')
plt.show()

# %% [markdown]
# The Clientele growth has decreased

# %%
plt.bar(revenue_df.Year, revenue_df.Revenue_Growth, color=(0.3, 0.8, 0.4));
plt.xlabel('Year')
plt.ylabel('Revenue Growth')
plt.title('Revenue Growth in % with Time')
plt.show()

# %% [markdown]
# The Revenue growth has decreased
